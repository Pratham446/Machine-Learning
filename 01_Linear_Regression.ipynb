# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
dff=pd.read_csv('homeprices.csv')
dff
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.xlabel('area'),plt.ylabel('price')
plt.scatter(dff.area,dff.price,color='red',marker='+')

# %%
# step 1 create a linear regression object 
reg=linear_model.LinearRegression()

# step 2 training the linear regresion model using avalable data points
reg.fit(df[['area']],df.price)

# now it ready to predict the price
reg.predict([[3500]])
# Out:
# D:\Installations\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([655873.28767123])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
# y=m*x+b
# prediction=reg.coef_* area that we want to predct + intercept

# %%
data=pd.read_csv('areas.csv')
data
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
p=reg.predict(data)
p
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
#creating a new column 
data['prices']=p
data
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
newdata=pd.read_csv('predction.csv')
# Disable scientific notation
pd.set_option('display.float_format', '{:,.2f}'.format)

newdata
# Out:
#     area       prices
# 0   1000   316,404.11
# 1   1500   384,297.95
# 2   2300   492,928.08
# 3   3540   661,304.79
# 4   4120   740,061.64
# 5   4560   799,808.22
# 6   5490   926,090.75
# 7   3460   650,441.78
# 8   4750   825,607.88
# 9   2300   492,928.08
# 10  9000 1,402,705.48
# 11  8600 1,348,390.41
# 12  7100 1,144,708.90

# %%
plt.scatter(dff.area,dff.price,color='red',marker='+')
plt.plot(dff.area,reg.predict(dff[['area']]),color='blue')

# %%
df=pd.read_csv('canada.csv')
df
# Out:
#     year  per capita income (US$)
# 0   1970                 3,399.30
# 1   1971                 3,768.30
# 2   1972                 4,251.18
# 3   1973                 4,804.46
# 4   1974                 5,576.51
# 5   1975                 5,998.14
# 6   1976                 7,062.13
# 7   1977                 7,100.13
# 8   1978                 7,247.97
# 9   1979                 7,602.91
# 10  1980                 8,355.97
# 11  1981                 9,434.39
# 12  1982                 9,619.44
# 13  1983                10,416.54
# 14  1984                10,790.33
# 15  1985                11,018.96
# 16  1986                11,482.89
# 17  1987                12,974.81
# 18  1988                15,080.28
# 19  1989                16,426.73
# 20  1990                16,838.67
# 21  1991                17,266.10
# 22  1992                16,412.08
# 23  1993                15,875.59
# 24  1994                15,755.82
# 25  1995                16,369.32
# ...

# %%
# step 1 create instance object
df.rename(columns={'per capita income (US$)': 'per_capita_income'}, inplace=True)

# %%
df.head(2)
# Out:
#    year  per_capita_income
# 0  1970           3,399.30
# 1  1971           3,768.30

# %%
plt.scatter(df.year,df.per_capita_income,color='red',marker='+')

# %%
# step 1 create instance object
reg=reg=linear_model.LinearRegression()

# step 2 training the linear regresion model using avalable data points
reg.fit(df[['year']],df.per_capita_income)

newdata=reg.predict(x[['year']])

# %%
x=pd.read_csv('Book1.csv')
x
# Out:
#     year
# 0   2017
# 1   2018
# 2   2019
# 3   2020
# 4   2021
# 5   2022
# 6   2023
# 7   2024
# 8   2025
# 9   2026
# 10  2027
# 11  2028
# 12  2029
# 13  2030

# %%
x['per_capita_income'] = newdata
x
# Out:
#     year  per_capita_income
# 0   2017          38,803.30
# 1   2018          39,631.76
# 2   2019          40,460.23
# 3   2020          41,288.69
# 4   2021          42,117.16
# 5   2022          42,945.62
# 6   2023          43,774.09
# 7   2024          44,602.55
# 8   2025          45,431.02
# 9   2026          46,259.48
# 10  2027          47,087.95
# 11  2028          47,916.41
# 12  2029          48,744.88
# 13  2030          49,573.34
